# %%
# tensorflow와 tf.keras를 임포트합니다
import tensorflow as tf
from tensorflow import keras

# 헬퍼(helper) 라이브러리를 임포트합니다
import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 2.3.1

# %%
fashion_mnist = keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
len(train_labels)
# Out:
# 60000

# %%
train_labels
# Out:
# array([9, 0, 0, ..., 3, 0, 5], dtype=uint8)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
len(test_labels)
# Out:
# 10000

# %%
plt.figure()
plt.imshow(train_images[0])
plt.colorbar()
plt.grid(False)
plt.show()

# %%
train_labels[:3]
# Out:
# array([9, 0, 0], dtype=uint8)

# %%
train_images = train_images / 255.0

test_images = test_images / 255.0

# %%
plt.figure(figsize=(10,10))
for i in range(55):
    plt.subplot(5,11,i+1)
    plt.imshow(train_images[i])
plt.show()

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(train_images, train_labels, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.5018 - accuracy: 0.8242
# Epoch 2/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3775 - accuracy: 0.8633
# Epoch 3/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3407 - accuracy: 0.8753
# Epoch 4/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3156 - accuracy: 0.8832
# Epoch 5/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2983 - accuracy: 0.8901
# Epoch 6/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2818 - accuracy: 0.8951
# Epoch 7/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2710 - accuracy: 0.8986
# Epoch 8/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2592 - accuracy: 0.9036
# Epoch 9/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2495 - accuracy: 0.9068
# Epoch 10/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2402 - accuracy: 0.9107

# %%
test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)

print('\n Test Acc:', test_acc)
print('\n Test Loss:', test_loss)
# Out:
# 313/313 - 0s - loss: 0.3373 - accuracy: 0.8813
#
#  Test Acc: 0.8812999725341797
#
#  Test Loss: 0.3373359739780426

# %%
predictions = model.predict(test_images)

# %%
predictions[0]
# Out:
# array([4.9940904e-06, 6.8457837e-07, 2.4348874e-09, 2.2172819e-09,
#        5.7682614e-06, 2.2964260e-04, 4.3649340e-08, 2.2872804e-01,
#        3.5892372e-06, 7.7102721e-01], dtype=float32)

# %%
np.argmax(predictions[0])
# Out:
# 9

# %%
test_labels[0]
# Out:
# 9
